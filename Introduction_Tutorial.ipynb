# %% [markdown]
# # Getting Your Computer Ready for Data Science:
# - We will primary use this resource as the base to getting your computer ready for data science and coding
# - https://neuraldatascience.io/b-setup/introduction/
#     - Recomendations:
#         - Install VS-code in your computer instead of running it on Github Codespace, it will be easier to open important files directly to your computer
#         - Installing Anaconda instead of mini-anaconda, as I´ve install mini-anaconda myself I ran into some errors like missing packages which will need to be manually installed.
#             - If some of the functions do not run as intented you will have to open powercell and enable this functions to run as sometimes windows does not led you run donwloaded comands on your computer
#                     - maybe check on this later to give a clear solution to this problem (youtube history)
#                     - Its with having problems installing the neural_data_science enviroment, sometimes when running the code "mamba env create -f neural_data_science.yml" its not permitted, you will have to allow this by
#                     - This is because of the execution policy of windows, in order to change it, open powercell in administration mode (right click on powercell and click on open as administrator)}
#                         - After that run this code. Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser
#                         - You will now be able to run the mamba env create -f neural_data_science.yml line of code.

# %% [markdown]
# - Throughout this tutorial, you will get familiarize with Github follow the steps of the link above

# %% [markdown]
# # Basic Information of Sources
# - In this part you will get to know the sources needed to understand this tutorial. It will cover sources important for the use, edit and making of the five cognitive tasks to measure cognitive performance in both lab (computer) and phone setting.
# - For lab setting we will be using Psychopy a free, open-source software application which uses Python to create, run and analyze congitive tasks.
# - For smartphone setting, the use of Javascript will be important for the creation of web and phone cognitive tasks. (more on this later)
# - Additional resources like Github, Pavlovia, Empath are discussed below

# %% [markdown]
# ## Github
# - Github is a web-based, cloud-hosted plataform which uses the Git version control ststem which help developers store, manage, track and share code.
# - It is important as it enables collaboration through features like repositories, pull requests and issue tracking which is fundamental for software development teams

# %% [markdown]
# ## Pavlovia
# - Pavlovia is an open-source, web based plataform which enables scientits to host, run and share online behavioral, psychological, and cognitive experiments. It acts as bridge between the code/tasks written in Psychopy and participants worldwide, which serves the behavioral science community with secure, cloud-based data storage and management.
# - website --> https://pavlovia.org/#main

# %% [markdown]
# ## Empath

# %% [markdown]
# ## Psychopy
#
# Psychopy is a free, open-source software package written in Python, designed for creating psychology, neuroscience, and psychophysics. It is useful for presenting stimuli and collect data using both the GUI-based builder window and the advanced "Coder" scripting which is what we will focus on.
#
# It is flexibile meaning that it allows for large complex experimental designs, as well as having online compatibility with Pavlovia which turns the experiments to JavaScript to run them directly in the web browser. It is also convinient as it runs in Windoes, Mac and Linux.
#
# What is important to know about psychopy is that in order for experiments to run in it, it has to be compatible with other versions of python depending on the experiment. The gold-standard for psychopy coding is python version 3.10 as of 2026.
#
# Thus is important that the kernel is set to the psyochopy enviroment meanwhile learning about psychopy during this tutorial.

# %% [markdown]
# # Using
# - The cognitive tasks used in this project are programmed in **PsychoPy** and hosted on **Pavlovia** for online data collection.
# - To run a task locally (on your computer), open the task folder in VS Code, select the `psychopy_env` kernel, and run the experiment script.
# - To run a task online, navigate to the Pavlovia project page and click **Pilot** or **Run**.
# - See the **[NBack_Task_Tutorial.ipynb](NBack_Task_Tutorial.ipynb)** notebook for a section-by-section walkthrough of the N-Back task code.

# %% [markdown]
# # Editing
# - Once you understand the structure of a task (see **[NBack_Task_Tutorial.ipynb](NBack_Task_Tutorial.ipynb)**), you can edit individual parameters without rewriting the whole experiment.
# - The key editable parameters are centralised at the top of the code (Section 2 of the tutorial) so you only need to change **one line** to customise the task.
#
# ## Example edits
#
# ### Change the colour of the square
# ```python
# # Original (blue square)
# SQUARE_COLOR = 'blue'
#
# # Changed to red
# SQUARE_COLOR = 'red'
# ```
#
# ### Change from 2-Back to 3-Back
# ```python
# # Original (2-back task)
# N_BACK = 2
#
# # Changed to 3-back — harder, requires remembering further back
# N_BACK = 3
# ```
#
# - After making a change, re-run the affected cells from the top of the relevant section downward.
# - Use the **Matplotlib preview cell** (Section 3 of the tutorial) to check visual changes instantly, without opening the full PsychoPy window.

# %% [markdown]
# # Making
# - here i guess from 0? using what we learn such as ai copilot assistant for coding
