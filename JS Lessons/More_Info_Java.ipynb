# %% [markdown]
# # Javascript.info
# In order to understand the basics of JavaScript, the tutorials on [Javascript.info](https://javascript.info/) will provide you with a solid foundation. This resource provides comprehensive lessons on various JavaScript topics, the topics that are most important for beginners who wish to edit ESM tasks include:
#
# - **Variables** - Learn how to declare and use variables in JavaScript, which are essential for storing and manipulating data.
#     - https://javascript.info/variables
#
# - **Data Types** - Understand the different data types in JavaScript, such as strings, numbers, booleans, and objects, which are crucial for handling data effectively.
#
#     - https://javascript.info/types
#
# - **Types Conversions** - Explore how to convert between different data types in JavaScript, which is important for ensuring that your code works correctly when handling various types of data.
#     - https://javascript.info/type-conversions
#
# - **Functions** - Explore how to create and use functions in JavaScript, which are fundamental for organizing code and performing tasks.
#     - https://javascript.info/function-basics
#
# - **Function Expression** - Learn about function expressions, which allow you to create functions as part of expressions and are useful for creating anonymous functions and closures.
#     - https://javascript.info/function-expression
#
# - **Objects** - Gain knowledge about objects in JavaScript, which are key for structuring data and creating complex applications.
#     - https://javascript.info/object
#
# - **Object Methods** - Learn about object methods, which are functions that are properties of objects and are essential for manipulating object data.
#     - https://javascript.info/object-methods
#
# - **Arrays** - Learn about arrays, which are used to store multiple values in a single variable and are essential for managing collections of data.
#     - https://javascript.info/array
#
# - **Classes** - Understand how to use classes in JavaScript, which are a blueprint for creating objects and are important for object-oriented programming.
#     - https://javascript.info/class
#
# - **Json** - Explore how to work with JSON (JavaScript Object Notation), a widely used format for data exchange, which is important for handling data in web applications.
#     - https://javascript.info/json
