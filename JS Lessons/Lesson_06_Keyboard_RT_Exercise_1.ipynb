// %% [markdown]
// # Lesson 06 Exercise 1 - Keyboard Response and RT
//
// Complete TODOs to capture key response accuracy and reaction time.

// %% [markdown]
// ## TODO exercise code for `tasks/student_task.js`

// %% [markdown]
// ```javascript
// if (window.__lesson6ExerciseGame) {
//   window.__lesson6ExerciseGame.destroy(true);
// }
//
// class ExerciseScene extends Phaser.Scene {
//   create() {
//     const cx = this.cameras.main.centerX;
//     const cy = this.cameras.main.centerY;
//
//     const expectedKey = "K";
//     const startTime = Date.now();
//
//     this.add.text(cx, cy - 60, "Press K", {
//       fontSize: "34px",
//       color: "#ffffff"
//     }).setOrigin(0.5);
//
//     const feedback = this.add.text(cx, cy + 30, "", {
//       fontSize: "24px",
//       color: "#aaddff"
//     }).setOrigin(0.5);
//
//     this.input.keyboard.on("keydown", (event) => {
//       // TODO 1: create endTime and rtMs
//
//       // TODO 2: compare pressed key to expectedKey (case-insensitive)
//
//       // TODO 3: if correct, show "Correct | RT: ... ms" in green
//       // TODO 4: else show "Incorrect | RT: ... ms" in red
//     });
//   }
// }
//
// window.__lesson6ExerciseGame = new Phaser.Game({
//   type: Phaser.AUTO,
//   parent: "phaser-game",
//   width: 800,
//   height: 420,
//   backgroundColor: "#1f1f2d",
//   scene: ExerciseScene
// });
// ```

// %%
const taskPath = "./tasks/student_task.js";
const taskCode = await Deno.readTextFile(taskPath);
play(taskCode);

// %% [markdown]
// ## Self-check
//
// - [ ] Reaction time appears in ms after key press.
// - [ ] Correct key gives green feedback.
// - [ ] Incorrect key gives red feedback.
