// %% [markdown]
// # Lesson 05 Exercise 1 - Trial Arrays and Object Fields
//
// Complete TODOs to build a small stimulus list using arrays and objects.

// %% [markdown]
// ## TODO exercise code for `tasks/student_task.js`

// %% [markdown]
// ```javascript
// if (window.__lesson5ExerciseGame) {
//   window.__lesson5ExerciseGame.destroy(true);
// }
//
// class ExerciseScene extends Phaser.Scene {
//   create() {
//     const cx = this.cameras.main.centerX;
//     const cy = this.cameras.main.centerY;
//
//     // TODO 1: Create an array named trials with 4 objects
//     // Each object should have: stimulus, correctKey
//     const trials = [];
//
//     let trialIndex = 0;
//
//     const label = this.add.text(cx, cy, "Press SPACE", {
//       fontSize: "28px",
//       color: "#ffffff"
//     }).setOrigin(0.5);
//
//     this.input.keyboard.on("keydown-SPACE", () => {
//       // TODO 2: if trialIndex < trials.length, show current stimulus using object field access
//       // Example style: trials[trialIndex].stimulus
//       // TODO 3: increment trialIndex
//       // TODO 4: else show "All trials shown"
//     });
//   }
// }
//
// window.__lesson5ExerciseGame = new Phaser.Game({
//   type: Phaser.AUTO,
//   parent: "phaser-game",
//   width: 800,
//   height: 420,
//   backgroundColor: "#182236",
//   scene: ExerciseScene
// });
// ```

// %%
const taskPath = "./tasks/student_task.js";
const taskCode = await Deno.readTextFile(taskPath);
play(taskCode);

// %% [markdown]
// ## Self-check
//
// - [ ] Trials are stored as an array of objects.
// - [ ] Stimulus text comes from object fields.
// - [ ] Task ends with `All trials shown`.
