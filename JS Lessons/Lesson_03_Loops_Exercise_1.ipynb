// %% [markdown]
// # Lesson 03 Exercise 1 - Loops for Trial Flow
//
// Complete the TODOs to generate trial labels with a loop and progress through them with `SPACE`.

// %% [markdown]
// ## TODO exercise code for `tasks/student_task.js`

// %% [markdown]
// ```javascript
// if (window.__lesson3ExerciseGame) {
//   window.__lesson3ExerciseGame.destroy(true);
// }
//
// class ExerciseScene extends Phaser.Scene {
//   create() {
//     const cx = this.cameras.main.centerX;
//     const cy = this.cameras.main.centerY;
//
//     let trialIndex = 0;
//     const maxTrials = 6;
//     const trialLabels = [];
//
//     // TODO 1: Fill trialLabels with a for loop from 1 to maxTrials
//     // Label format: "Trial X / maxTrials"
//
//     const label = this.add.text(cx, cy, "Press SPACE to start", {
//       fontSize: "26px",
//       color: "#ffffff"
//     }).setOrigin(0.5);
//
//     this.input.keyboard.on("keydown-SPACE", () => {
//       // TODO 2: if trialIndex < maxTrials, set text from trialLabels[trialIndex]
//       // TODO 3: increment trialIndex
//       // TODO 4: else set label to "Task complete"
//     });
//   }
// }
//
// window.__lesson3ExerciseGame = new Phaser.Game({
//   type: Phaser.AUTO,
//   parent: "phaser-game",
//   width: 800,
//   height: 420,
//   backgroundColor: "#202437",
//   scene: ExerciseScene
// });
// ```

// %%
const taskPath = "./tasks/student_task.js";
const taskCode = await Deno.readTextFile(taskPath);
play(taskCode);

// %% [markdown]
// ## Self-check
//
// - [ ] Labels are generated by a loop.
// - [ ] `SPACE` moves from Trial 1 to Trial 6.
// - [ ] Final state shows `Task complete`.
