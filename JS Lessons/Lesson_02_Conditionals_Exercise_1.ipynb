// %% [markdown]
// # Lesson 02 Exercise 1 - Conditionals in ESM Task Logic
//
// This exercise notebook practices `if / else if / else`, comparisons, and logical operators.
//
// You will complete TODOs in `tasks/student_task.js`, then run with `play(taskCode)`.

// %% [markdown]
// ## Exercise goals
//
// By the end, your task should:
//
// 1. Start with `Waiting to start`.
// 2. Show `Trial running` during middle trials.
// 3. Show `Task complete` at the end.
// 4. Show `Task paused` when a pause flag is true.

// %% [markdown]
// ## Step 0: Quick notebook warm-up
//
// Run this cell and check the output.

// %%
const expectedKey = "SPACE";
const pressedKey = "SPACE";

let feedback = "";
if (pressedKey === expectedKey) {
  feedback = "Correct";
} else {
  feedback = "Incorrect";
}

feedback

// %% [markdown]
// ## Step 1: Paste this starter in `tasks/student_task.js`
//
// Then complete each TODO.

// %% [markdown]
// ```javascript
// if (window.__lesson2ExerciseGame) {
//   window.__lesson2ExerciseGame.destroy(true);
// }
//
// class ExerciseScene extends Phaser.Scene {
//   create() {
//     const cx = this.cameras.main.centerX;
//     const cy = this.cameras.main.centerY;
//
//     let trialIndex = 0;
//     const maxTrials = 5;
//     let isPaused = false;
//
//     const title = this.add.text(cx, cy - 80, "Lesson 02 Exercise", {
//       fontSize: "30px",
//       color: "#ffffff"
//     }).setOrigin(0.5);
//
//     const statusLabel = this.add.text(cx, cy, "", {
//       fontSize: "28px",
//       color: "#aaddff"
//     }).setOrigin(0.5);
//
//     const helpLabel = this.add.text(cx, cy + 80, "SPACE = next trial, P = pause/resume", {
//       fontSize: "20px",
//       color: "#dddddd"
//     }).setOrigin(0.5);
//
//     function updateStatus() {
//       // TODO 1: If paused, set text to "Task paused"
//       // TODO 2: Else if trialIndex === 0, set text to "Waiting to start"
//       // TODO 3: Else if trialIndex > 0 && trialIndex < maxTrials, set text to "Trial running"
//       // TODO 4: Else set text to "Task complete"
//     }
//
//     updateStatus();
//
//     this.input.keyboard.on("keydown-SPACE", () => {
//       // TODO 5: Only increment trialIndex when NOT paused AND trialIndex < maxTrials
//       // Example condition style: if (!isPaused && trialIndex < maxTrials) { ... }
//
//       updateStatus();
//     });
//
//     this.input.keyboard.on("keydown-P", () => {
//       // TODO 6: Toggle pause state with a conditional-style expression
//       // Hint: isPaused = !isPaused;
//
//       updateStatus();
//     });
//   }
// }
//
// window.__lesson2ExerciseGame = new Phaser.Game({
//   type: Phaser.AUTO,
//   parent: "phaser-game",
//   width: 800,
//   height: 420,
//   backgroundColor: "#1d1d2a",
//   scene: ExerciseScene
// });
// ```

// %% [markdown]
// ## Step 2: Runner cell (do not edit)
//
// Run this after saving `tasks/student_task.js`.

// %%
const taskPath = "./tasks/student_task.js";
const taskCode = await Deno.readTextFile(taskPath);
play(taskCode);

// %% [markdown]
// ## Step 3: Self-check
//
// Confirm all checks:
//
// - [ ] Start state shows `Waiting to start`.
// - [ ] Pressing `SPACE` advances status to `Trial running`.
// - [ ] Pressing `P` shows `Task paused`.
// - [ ] While paused, `SPACE` does not increment trial.
// - [ ] At max trials, status shows `Task complete`.

// %% [markdown]
// ## Reflection (2-3 lines)
//
// 1. Which condition was hardest to implement and why?
// 2. Which bug did you find first, and how did you fix it?
