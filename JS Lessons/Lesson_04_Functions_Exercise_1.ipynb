// %% [markdown]
// # Lesson 04 Exercise 1 - Reuse Functions in a Task
//
// Complete TODOs to modularize task behavior with reusable functions.

// %% [markdown]
// ## TODO exercise code for `tasks/student_task.js`

// %% [markdown]
// ```javascript
// if (window.__lesson4ExerciseGame) {
//   window.__lesson4ExerciseGame.destroy(true);
// }
//
// class ExerciseScene extends Phaser.Scene {
//   create() {
//     const cx = this.cameras.main.centerX;
//     const cy = this.cameras.main.centerY;
//
//     let trialIndex = 0;
//     const maxTrials = 4;
//
//     const label = this.add.text(cx, cy, "", {
//       fontSize: "26px",
//       color: "#ffffff"
//     }).setOrigin(0.5);
//
//     // TODO 1: Create getStatus(index, max) and return:
//     // "Waiting to start", "Trial running", or "Task complete"
//
//     // TODO 2: Create paintStatus(labelObj, statusText)
//     // Set text, and if complete set green color.
//
//     // TODO 3: Call both functions to set initial label
//
//     this.input.keyboard.on("keydown-SPACE", () => {
//       if (trialIndex < maxTrials) {
//         trialIndex = trialIndex + 1;
//       }
//
//       // TODO 4: Update label using your functions
//     });
//   }
// }
//
// window.__lesson4ExerciseGame = new Phaser.Game({
//   type: Phaser.AUTO,
//   parent: "phaser-game",
//   width: 800,
//   height: 420,
//   backgroundColor: "#1a2235",
//   scene: ExerciseScene
// });
// ```

// %%
const taskPath = "./tasks/student_task.js";
const taskCode = await Deno.readTextFile(taskPath);
play(taskCode);

// %% [markdown]
// ## Self-check
//
// - [ ] Task uses at least 2 custom functions.
// - [ ] Status text updates correctly per trial.
// - [ ] Completion status changes color.
